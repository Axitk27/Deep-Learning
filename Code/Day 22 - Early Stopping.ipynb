# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9125 - loss: 0.1662 - val_accuracy: 0.6500 - val_loss: 0.8073
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9125 - loss: 0.1663 - val_accuracy: 0.6500 - val_loss: 0.8064
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9125 - loss: 0.1666 - val_accuracy: 0.6500 - val_loss: 0.8060
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9125 - loss: 0.1667 - val_accuracy: 0.6500 - val_loss: 0.8074
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9125 - loss: 0.1667 - val_accuracy: 0.6500 - val_loss: 0.8114
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9125 - loss: 0.1661 - val_accuracy: 0.6500 - val_loss: 0.8145
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9375 - loss: 0.1666 - val_accuracy: 0.6500 - val_loss: 0.8129
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9375 - loss: 0.1671 - val_accuracy: 0.6500 - val_loss: 0.8130
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9375 - loss: 0.1664 - val_accuracy: 0.6500 - val_loss: 0.8133
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9125 - loss: 0.1660 - val_accuracy: 0.6500 - val_loss: 0.8132
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9250 - loss: 0.1659 - val_accuracy: 0.6500 - val_loss: 0.8168
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9250 - loss: 0.1674 - val_accuracy: 0.6500 - val_loss: 0.8195
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9250 - loss: 0.1664 - val_accuracy: 0.6500 - val_loss: 0.8233
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9250 - loss: 0.1657 - val_accuracy: 0.6500 - val_loss: 0.8234

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test, clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 11s 1ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_decision_regions(X_test, y_test, clf = model, legend=2)
#       2 plt.show()
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\mlxtend\plotting\decision_regions.py:306, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     300 contourf_kwargs_default = {"alpha": 0.45, "antialiased": True}
#     301 contourf_kwargs = format_kwarg_dictionaries(
#     302     default_kwargs=contourf_kwargs_default,
#     303     user_kwargs=contourf_kwargs,
#     304     protected_keys=["colors", "levels"],
#     305 )
# --> 306 cset = ax.contourf(
#     307     xx,
#     308     yy,
#     309     Z_indexed,
#     310     colors=colors,
#     311     levels=np.arange(Z.max() + 2) - 0.5,
#     312     **contourf_kwargs,
#     313 )
#     315 contour_kwargs_default = {"linewidths": 0.5, "colors": "k", "antialiased": True}
#     316 contour_kwargs = format_kwarg_dictionaries(
#     317     default_kwargs=contour_kwargs_default,
#     318     user_kwargs=contour_kwargs,
#     319     protected_keys=[],
#     320 )
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\axes\_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)   6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:703, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     699 if self.negative_linestyles is None:
#     700     self.negative_linestyles = \
#     701         mpl.rcParams['contour.negative_linestyle']
# --> 703 kwargs = self._process_args(*args, **kwargs)
#     704 self._process_levels()
#     706 self._extend_min = self.extend in ['min', 'both']
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:1321, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1318         corner_mask = mpl.rcParams['contour.corner_mask']
#    1319 self._corner_mask = corner_mask
# -> 1321 x, y, z = self._contour_args(args, kwargs)
#    1323 contour_generator = contourpy.contour_generator(
#    1324     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1325     line_type=contourpy.LineType.SeparateCode,
#    1326     fill_type=contourpy.FillType.OuterCode,
#    1327     chunk_size=self.nchunk)
#    1329 t = self.get_transform()
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:1365, in QuadContourSet._contour_args(self, args, kwargs)
#    1363 else:
#    1364     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
# -> 1365 z = ma.masked_invalid(z, copy=False)
#    1366 self.zmax = z.max().astype(float)
#    1367 self.zmin = z.min().astype(float)
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\numpy\ma\core.py:2418, in masked_invalid(a, copy)
#    2390 """
#    2391 Mask an array where invalid values occur (NaNs or infs).
#    2392
#    (...)   2415
#    2416 """
#    2417 a = np.array(a, copy=None, subok=True)
# -> 2418 res = masked_where(~(np.isfinite(a)), a, copy=copy)
#    2419 # masked_invalid previously never returned nomask as a mask and doing so
#    2420 # threw off matplotlib (gh-22842).  So use shrink=False:
#    2421 if res._mask is nomask:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %% [markdown]
# # Early Stopping

# %%
model = Sequential()

model.add(Dense(256, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
callback = EarlyStopping(
    monitor="val_loss",
    min_delta=0.00001,
    patience=20,
    verbose=1,
    mode="auto",
    baseline=None,
    restore_best_weights=False
)

# %%
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=500, callbacks=callback)
# Out:
# Epoch 1/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.4750 - loss: 0.6946 - val_accuracy: 0.5500 - val_loss: 0.6894
# Epoch 2/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4625 - loss: 0.6920 - val_accuracy: 0.5500 - val_loss: 0.6940
# Epoch 3/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.5125 - loss: 0.6905 - val_accuracy: 0.4500 - val_loss: 0.6973
# Epoch 4/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5000 - loss: 0.6883 - val_accuracy: 0.4500 - val_loss: 0.6993
# Epoch 5/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5375 - loss: 0.6872 - val_accuracy: 0.4500 - val_loss: 0.7023
# Epoch 6/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.5500 - loss: 0.6862 - val_accuracy: 0.4500 - val_loss: 0.7052
# Epoch 7/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5250 - loss: 0.6848 - val_accuracy: 0.4000 - val_loss: 0.7078
# Epoch 8/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.5375 - loss: 0.6839 - val_accuracy: 0.4000 - val_loss: 0.7109
# Epoch 9/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5625 - loss: 0.6832 - val_accuracy: 0.4000 - val_loss: 0.7140
# Epoch 10/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.5500 - loss: 0.6829 - val_accuracy: 0.4000 - val_loss: 0.7174
# Epoch 11/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5500 - loss: 0.6821 - val_accuracy: 0.4000 - val_loss: 0.7197
# Epoch 12/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.5500 - loss: 0.6814 - val_accuracy: 0.4000 - val_loss: 0.7215
# Epoch 13/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.5500 - loss: 0.6809 - val_accuracy: 0.4000 - val_loss: 0.7223
# Epoch 14/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5500 - loss: 0.6801 - val_accuracy: 0.4000 - val_loss: 0.7237
# Epoch 15/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5750 - loss: 0.6798 - val_accuracy: 0.4000 - val_loss: 0.7249
# Epoch 16/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5750 - loss: 0.6791 - val_accuracy: 0.4000 - val_loss: 0.7250
# Epoch 17/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.5750 - loss: 0.6784 - val_accuracy: 0.4000 - val_loss: 0.7246
# Epoch 18/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.5875 - loss: 0.6779 - val_accuracy: 0.4000 - val_loss: 0.7242
# Epoch 19/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5750 - loss: 0.6774 - val_accuracy: 0.4000 - val_loss: 0.7236
# Epoch 20/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5625 - loss: 0.6767 - val_accuracy: 0.4000 - val_loss: 0.7239
# Epoch 21/500
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5625 - loss: 0.6761 - val_accuracy: 0.4000 - val_loss: 0.7240
# Epoch 21: early stopping

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
plt.show()
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 19s 2ms/step
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 plot_decision_regions(X_test, y_test.ravel(), clf = model, legend=2)
#       2 plt.show()
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\mlxtend\plotting\decision_regions.py:306, in plot_decision_regions(X, y, clf, feature_index, filler_feature_values, filler_feature_ranges, ax, X_highlight, zoom_factor, legend, hide_spines, markers, colors, scatter_kwargs, contourf_kwargs, contour_kwargs, scatter_highlight_kwargs, n_jobs)
#     300 contourf_kwargs_default = {"alpha": 0.45, "antialiased": True}
#     301 contourf_kwargs = format_kwarg_dictionaries(
#     302     default_kwargs=contourf_kwargs_default,
#     303     user_kwargs=contourf_kwargs,
#     304     protected_keys=["colors", "levels"],
#     305 )
# --> 306 cset = ax.contourf(
#     307     xx,
#     308     yy,
#     309     Z_indexed,
#     310     colors=colors,
#     311     levels=np.arange(Z.max() + 2) - 0.5,
#     312     **contourf_kwargs,
#     313 )
#     315 contour_kwargs_default = {"linewidths": 0.5, "colors": "k", "antialiased": True}
#     316 contour_kwargs = format_kwarg_dictionaries(
#     317     default_kwargs=contour_kwargs_default,
#     318     user_kwargs=contour_kwargs,
#     319     protected_keys=[],
#     320 )
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
#    1531                   or bound.kwargs.get(label_namer))
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\axes\_axes.py:6797, in Axes.contourf(self, *args, **kwargs)
#    6786 """
#    6787 Plot filled contours.
#    6788
#    (...)   6794 %(contour_doc)s
#    6795 """
#    6796 kwargs['filled'] = True
# -> 6797 contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6798 self._request_autoscale_view()
#    6799 return contours
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:703, in ContourSet.__init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, colorizer, extend, antialiased, nchunk, locator, transform, negative_linestyles, clip_path, *args, **kwargs)
#     699 if self.negative_linestyles is None:
#     700     self.negative_linestyles = \
#     701         mpl.rcParams['contour.negative_linestyle']
# --> 703 kwargs = self._process_args(*args, **kwargs)
#     704 self._process_levels()
#     706 self._extend_min = self.extend in ['min', 'both']
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:1321, in QuadContourSet._process_args(self, corner_mask, algorithm, *args, **kwargs)
#    1318         corner_mask = mpl.rcParams['contour.corner_mask']
#    1319 self._corner_mask = corner_mask
# -> 1321 x, y, z = self._contour_args(args, kwargs)
#    1323 contour_generator = contourpy.contour_generator(
#    1324     x, y, z, name=self._algorithm, corner_mask=self._corner_mask,
#    1325     line_type=contourpy.LineType.SeparateCode,
#    1326     fill_type=contourpy.FillType.OuterCode,
#    1327     chunk_size=self.nchunk)
#    1329 t = self.get_transform()
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\matplotlib\contour.py:1365, in QuadContourSet._contour_args(self, args, kwargs)
#    1363 else:
#    1364     raise _api.nargs_error(fn, takes="from 1 to 4", given=nargs)
# -> 1365 z = ma.masked_invalid(z, copy=False)
#    1366 self.zmax = z.max().astype(float)
#    1367 self.zmin = z.min().astype(float)
#
# File d:\Education\Extra\Artificial Intelligence\Deep-Learning\.venv_tf312\Lib\site-packages\numpy\ma\core.py:2418, in masked_invalid(a, copy)
#    2390 """
#    2391 Mask an array where invalid values occur (NaNs or infs).
#    2392
#    (...)   2415
#    2416 """
#    2417 a = np.array(a, copy=None, subok=True)
# -> 2418 res = masked_where(~(np.isfinite(a)), a, copy=copy)
#    2419 # masked_invalid previously never returned nomask as a mask and doing so
#    2420 # threw off matplotlib (gh-22842).  So use shrink=False:
#    2421 if res._mask is nomask:
#
# TypeError: ufunc 'isfinite' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
